# %% [markdown]
# # Apprentissage Non supervisé KMS

# %% [markdown]
# non superviser la data ne contien pas les featurs et les label , la machine en se basent sur des critere pour fair du clustereing Algo K-means
# en cas de problem:!pip install --upgrade scikit-learn numpy threadpoolctl
# os.environ["OMP_NUM_THREADS"] = "1"os.environ["MKL_NUM_THREADS"] = "1"

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
#Data
X,y = make_blobs(n_samples = 200 , centers=3, cluster_std=0.5, random_state=0)
plt.scatter(X[:,0],X[:,1])
plt.title( 'Nuage de point')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Générer des données de test
X, y = make_blobs(n_samples=200, centers=3, cluster_std=0.5, random_state=2)

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis', marker='o', edgecolor='k', s=50)

plt.title('Scatter Plot of Blobs')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')


handles, labels = plt.gca().get_legend_handles_labels()
unique_labels = set(y)
legend_labels = [f'Cluster {label}' for label in unique_labels]

plt.legend(handles, legend_labels, title='Clusters')

plt.show()

# %%
#model = KMeans(n_clusters=3, max_iter=300, n_init = 10, init = K-Means++) #tous les paramettre facultatif
model = KMeans(n_clusters=3)#model de donné de depart
model.fit(X)
model.labels_
# Out:
# array([2, 2, 2, 1, 2, 2, 0, 1, 2, 1, 2, 0, 2, 1, 1, 1, 0, 2, 0, 2, 2, 2,
#        2, 2, 1, 2, 2, 1, 0, 0, 0, 2, 1, 0, 2, 2, 1, 1, 2, 1, 0, 1, 2, 0,
#        2, 1, 0, 1, 0, 0, 1, 0, 0, 1, 2, 0, 0, 2, 0, 0, 1, 1, 2, 1, 1, 2,
#        1, 0, 1, 0, 2, 2, 2, 1, 0, 1, 2, 1, 2, 2, 0, 0, 1, 0, 0, 1, 0, 1,
#        0, 2, 0, 1, 2, 0, 1, 1, 1, 1, 2, 0, 2, 0, 2, 1, 0, 0, 1, 1, 2, 1,
#        1, 1, 0, 1, 1, 0, 0, 0, 0, 1, 2, 0, 0, 2, 2, 2, 1, 0, 0, 2, 2, 0,
#        1, 1, 0, 1, 2, 1, 0, 0, 2, 2, 1, 2, 0, 1, 1, 1, 1, 2, 2, 0, 2, 1,
#        2, 0, 0, 0, 2, 2, 1, 1, 0, 0, 2, 0, 1, 2, 2, 0, 0, 2, 0, 1, 1, 1,
#        0, 0, 2, 2, 0, 2, 0, 0, 1, 2, 2, 1, 1, 2, 1, 1, 0, 2, 1, 0, 2, 1,
#        0, 0])

# %%
model.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=model.predict(X), cmap='viridis', marker='o', edgecolor='k', s=50)
plt.scatter(model.cluster_centers_[:,0],model.cluster_centers_[:,1],c='b') # affiche le centroid
#model.inertia_ #calcukle la plus petit distance entre les point
model.score(X)
# Out:
# -106.62639187362812

# %%
plt.scatter(model.cluster_centers_[:,0],model.cluster_centers_[:,1])#position du centroid

# %%
liste = []
k_al = range(1,30)
for k in k_al :
    model = KMeans(n_clusters=k).fit(X)
    liste.append(model.inertia_)


plt.plot(k_al,liste)
plt.xlabel(' K clusters')
plt.ylabel('Fonction inertia')
plt.show()

# %%
#isolation Forest
# Générer des données de test
X, y = make_blobs(n_samples=20, centers=1, cluster_std=0.3, random_state=2)
X[-1,: ]= np.array([2.25,5])

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis', marker='o', edgecolor='k', s=50)

plt.title('Scatter Plot of Blobs')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')


handles, labels = plt.gca().get_legend_handles_labels()
unique_labels = set(y)
legend_labels = [f'Cluster {label}' for label in unique_labels]

plt.legend(handles, legend_labels, title='Clusters')

plt.show()

# %%
from sklearn.ensemble import IsolationForest

# %%
model = IsolationForest(contamination=0 -- 0.01)

# %%
model.fit(X)
# Out:
# IsolationForest(contamination=0.01)

# %%
plt.scatter(X[:, 0], X[:, 1], c=model.predict(X), cmap='viridis', marker='o', edgecolor='k', s=50)

# %% [markdown]
# Reduction

# %%
from sklearn.decomposition import PCA

model = PCA (n_components= 2)

# %%
model.fit_transform(X)#transforme le model et la variance
# Out:
# array([[-8.34355974e-01, -5.59287333e-02],
#        [-3.35276329e-02, -1.29114530e-01],
#        [-4.00404585e-01, -4.52342662e-02],
#        [-3.18079060e-01, -1.44982553e-01],
#        [-1.11736470e+00,  3.22674961e-01],
#        [-8.86861732e-01,  5.79341710e-01],
#        [-4.20617364e-01,  6.04728250e-01],
#        [-1.08289156e+00,  1.03807472e-01],
#        [-8.89829481e-01,  2.64976572e-01],
#        [-9.49444466e-01, -3.45124824e-01],
#        [-1.11507985e-01,  1.05072706e-01],
#        [-1.06287746e+00, -2.31344729e-01],
#        [-8.74561223e-01, -3.37720506e-01],
#        [-8.50781503e-01,  1.06789562e-01],
#        [-5.83013194e-01, -9.72828518e-02],
#        [-1.06602741e+00, -3.74890092e-01],
#        [-5.39538919e-01,  1.07081413e-02],
#        [-1.00951483e+00, -2.84401050e-01],
#        [-1.13304801e+00, -3.89113342e-02],
#        [ 1.41642471e+01, -1.31639050e-02]])

# %%
X.shape
# Out:
# (20, 2)

# %%
from sklearn.datasets import load_digits

digits = load_digits()
images = digits.images
X = digits.data
y = digits.target

plt.imshow(images[51])

# %%
X.shape
# Out:
# (1797, 64)

# %%
model =PCA(n_components=2)

# %%
model.fit_transform(X)
# Out:
# array([[ -1.25946221,  21.27487175],
#        [  7.95760843, -20.76869173],
#        [  6.99192021,  -9.95597885],
#        ...,
#        [ 10.80128969,  -6.96027023],
#        [ -4.87209744,  12.42394548],
#        [ -0.34438358,   6.36553261]])

# %%
New_X = model.fit_transform(X)

# %%
plt.scatter(New_X[: ,0], New_X[:,1], c=y)
plt.colorbar()

# %%
model.components_
# Out:
# array([[ 1.11022302e-16, -1.73094615e-02, -2.23428813e-01,
#         -1.35913323e-01, -3.30323285e-02, -9.66341230e-02,
#         -8.32947043e-03,  2.26899501e-03, -3.20516236e-04,
#         -1.19308879e-01, -2.44451669e-01,  1.48512701e-01,
#         -4.67319379e-02, -2.17740746e-01, -1.48137003e-02,
#          4.47779266e-03, -4.94135811e-05, -7.95419054e-02,
#          8.33951348e-02,  2.15915295e-01, -1.72126791e-01,
#         -1.63712064e-01,  2.86444548e-02,  4.23251914e-03,
#          9.85488731e-05,  6.42319396e-02,  2.54093341e-01,
#         -3.56771249e-02, -2.09462581e-01, -4.31311225e-02,
#          5.13118899e-02,  2.13422755e-04,  0.00000000e+00,
#          1.59950900e-01,  3.68690813e-01,  1.64406872e-01,
#          8.52008064e-02,  3.72982438e-02,  2.15866825e-02,
#          0.00000000e+00,  1.28865581e-03,  1.06945284e-01,
#          3.03067450e-01,  2.47813033e-01,  2.09637324e-01,
#          1.22325081e-02, -3.69458834e-02,  1.61484912e-03,
# ...

# %%
model.components_

# %%
model = PCA(n_components =28)
New_X = model.fit_transform(X)
np.argmax(np.cumsum(model.explained_variance_ratio_) > 0.95)
model.fit_transform(New_X)
# Out:
# array([[ -1.25946651,  21.27488346,  -9.46305494, ...,   2.28006645,
#           3.69731417,  -0.9595381 ],
#        [  7.95761123, -20.76869898,   4.43950622, ...,   0.12495392,
#           2.17491711,  -0.43420875],
#        [  6.99192296,  -9.95598642,   2.95855808, ...,   0.17170395,
#           4.2264885 ,   2.16939502],
#        ...,
#        [ 10.80128384,  -6.96025218,   5.59955466, ...,   4.45243781,
#          -3.58463462,   1.69243269],
#        [ -4.87210017,  12.42395359, -10.17086635, ...,  -2.68741889,
#           3.2443819 ,   1.0179878 ],
#        [ -0.34438958,   6.36554909,  10.77370877, ...,   0.41842379,
#          -3.03050158,   1.27372865]])
